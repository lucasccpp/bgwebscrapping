# %%
import pandas as pd
import csv
path_base = 'G:\\Meu Drive\\MBA - DS - ESALQ\\TCC\\ProjetoTCC_20220321\\003-storage\\001-raw\\bgg_DetalhesJogos.csv'
path_base2 = 'G:\\Meu Drive\\MBA - DS - ESALQ\\TCC\\ProjetoTCC_20220321\\003-storage\\001-raw\\ludopedia_DetalhesJogos.csv'
path_raw = '003-storage/001-raw/'
file_raw_list = 'bgg_gamelist.csv'
file_raw_detalhe = 'bgg_DetalhesJogos.csv'

path_curated = '003-storage/002-curated/'
file_curated_all = 'bgg_all.csv'

file_curated_DimCategoria = 'bgg_DimCategoria.csv'
file_curated_DimMecanica = 'bgg_DimMecanica.csv'
file_curated_DimArtista = 'bgg_DimArtista.csv'
file_curated_DimEditora = 'bgg_DimEditora.csv'
file_curated_DimDesigner = 'bgg_DimDesigner.csv'
file_curated_DimBoardgame = 'bgg_DimBoardgame.csv'
file_curated_FactBoardGameRelease = 'bgg_FactBoardGameRelease.csv'

# %%
dfTempList = pd.read_csv(path_base2,sep=';')

# %%
dfTempList
# Out:
#      Unnamed: 0   id  jogoAno     jogoIdade jogoTempJogo   jogoQtJogadores  \
# 0             0    1     2016  Idade  12 +       120 min  1 a 5 jogadores
# 1             0    2     2017  Idade  14 +       150 min  1 a 4 jogadores
# 2             0    3     2017  Idade  12 +       120 min  1 a 4 jogadores
# 3             0    4     2012  Idade  14 +       100 min  2 a 5 jogadores
# 4             0    5     2017  Idade  13 +       180 min  2 a 4 jogadores
# ..          ...  ...      ...           ...          ...               ...
# 149           0  150     2005  Idade  12 +       360 min  3 a 6 jogadores
# 150           0  151     2014  Idade  14 +       100 min  2 a 5 jogadores
# 151           0  152     1995  Idade  12 +        90 min  2 a 5 jogadores
# 152           0  153     2002  Idade  14 +        90 min  2 a 4 jogadores
# 153           0  154     2021  Idade  14 +       120 min  1 a 4 jogadores
#
#         jogoMiolosDesigner  jogoMiolosArtista     jogoMiolosEditora  \
# 0          Jacob Fryxelius    Isaac Fryxelius       Meeple BR Jogos
# 1         Jens Drögemüller    Dennis Lohausen            Grok Games
# 2           Isaac Childres   Alexandr Elichev             Galápagos
# 3         Jens Drögemüller    Dennis Lohausen            Grok Games
# 4           Martin Wallace      Lina Cossette      Conclave Editora
# ..                     ...                ...                   ...
# 149  Christian T. Petersen    Scott Schomburg  Fantasy Flight Games
# 150       Jonathan Gilmour    Fernanda Suarez             Galápagos
# 151        Wolfgang Kramer     Doris Matthäus      Rio Grande Games
# 152       Michael Kiesling    Walter Pepperle      Conclave Editora
# 153            Nate French  Christopher Hosch             Galápagos
#
#      jogoStatTem  jogoStatQuer  jogoStatTeve  jogoStatFavorito  \
# 0           4079          2337           368              1091
# 1           1484          1952           204               395
# 2           1494          1652           120               359
# 3           2939          2820           473               948
# 4            880           753           130               164
# ..           ...           ...           ...               ...
# 149          216           317           111                84
# 150         2389          1134           520               286
# 151          207           662            49                56
# 152          997           613           221                61
# 153          303           220             8                27
#
#                                        jogoResumoTexto
# 0    Nos anos de 2400, a humanidade começa a terraf...
# 1    Projeto Gaia é um novo jogo na linha de Terra ...
# 2    Gloomhaven é um jogo de combate tático inspira...
# 3    Em Terra Mystica habitam 14 povos diferentes e...
# 4    Brass: Lancashire - publicado pela primeira ve...
# ..                                                 ...
# 149  Twilight Imperium Third Edition é um jogo épic...
# 150  "Crossroads" é uma nova série da Plaid Hat Gam...
# 151  Neste jogo vencedor do prêmio Spiel des Jahres...
# 152  Mexica traça o desenvolvimento da cidade de me...
# 153  Arkham Horror: The Card Game é um jogo para 1 ...
#
# [154 rows x 14 columns]
